# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a =  2
b = 2
s = np.linspace(0, 1.0, 100)
y1 = beta.pdf(s, 2, 2)
plt.title('ABC')
plt.plot(s,y1)

plt.show()

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a =  2
b = 2
s = np.linspace(0.5, 1.0, 100)
y2 = beta.pdf(s, 42, 12)

plt.plot(s,y2)

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a =  2
b = 2
s = np.linspace(0.5, 1.0, 100)
y3 = beta.pdf(s, 59, 25)

plt.plot(s,y3)

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a =  2
b = 2
s = np.linspace(0.5, 1.0, 100)
y4 = beta.pdf(s, 129, 55)

plt.plot(s,y4)
